# %%
def print_factor(x):
    print("Factors is:")
    for i in range(2, x):
        if x % i == 0:
            print(i, end=" \n")

# %%
l = [52633, 8137, 1024, 999]
for num in l:
    print_factor(num)
# Out:
# Factors is:
# 7
# 73
# 103
# 511
# 721
# 7519
# Factors is:
# 79
# 103
# Factors is:
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# Factors is:
# 3
# 9
# 27
# 37
# 111
# 333
